# %% [markdown]
# <a href="https://colab.research.google.com/github/2ufkpfb9daxnik/assignments5/blob/main/%E8%AA%B2%E9%A1%8C05_21_NH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **プログラムの名称**
# ルパン三世タイトルコール風
# ## **概要**
# ColabTurtleで入力されたひらがなをルパン三世のタイトルコール風に表示します。
#
# ## **操作方法**
# 「プログラムの実行に必要なパッケージのインストール」を実行してください。「サブ処理」のtitleにタイトルコールにしてほしいひらがなの文字列を入力してください。その後「サブ処理」を実行してください。その後「メイン処理」を実行してください。<br>
# 小文字の「ぁ」「ぃ」「ぅ」「ぇ」「ぉ」「っ」「ゃ」「ゅ」「ょ」は大文字と同じとみなされます。ひらがな以外の文字があると無視されます。
#
# ## **制作者のコメント**
# 最近君たちはどう生きるかを見て宮崎駿に関わるものでかつすでに知っている物や技術で作れると嬉しいなと思ったのでこれにしました。でも調べると宮崎駿が主に担当していた第1期ではなく第2期からこのタイトルコールは使われ始めたらしいです。
#
# ## **作成時間**
# 作成時間：**約10時間**<br>

# %%
#@title プログラムの実行に必要なパッケージのインストール
# !pip install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=ba0f1650988454217849930d55fcd34020627675f253cbd39d2c4da7d39da267
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
#@title 初期化 ( %reset -f )
# %reset -f

# %%
#@title サブ処理
# 各種ライブラリのインポート
# データやパラメータ設定
# 関数やクラスなどの定義
import ColabTurtle.Turtle as t
import time
title = "\u304D\u307F\u305F\u3061\u306F\u3069\u3046\u3044\u304D\u308B\u304B "#@param{type:"string"}
title_length = len(title)
def draw(input):
  if input == 'あ'or input == 'ぁ':#あを描画
    t.up();t.goto(420,236.25);t.right(90);t.down()#1画目
    for i in range(10):
      t.forward(28);t.left(1)
    t.up();t.goto(560,157.5);t.seth(110);t.down();a = 3#2画目
    for i in range(13):
      t.left(a);t.forward(28)
    t.up();t.goto(650,300);t.seth(100);t.down();a = 1#3画目
    for i in range(20):
      t.forward(10);t.right(a);a = a*1.111
    for i in range(15):
      t.forward(10);t.right(0.5)
    for i in range(5):
      t.forward(0.5);t.right(15)
    for i in range(5):
      t.forward(15);t.right(7)
    for i in range(10):
      t.forward(5);t.right(5)
    for i in range(27):
      t.forward(10);t.right(1)
    for i in range(40):
      t.right(2);t.forward(2)
    for i in range(10):
      t.forward(15);t.right(4)
  elif input == 'い'or input == 'ぃ':#いを描画
    t.up();t.goto(420,157.5);t.seth(100);t.down()#1画目
    for i in range(30):
      t.forward(10);t.left(1)
    t.seth(300);t.forward(50);t.up();t.goto(700,180);t.seth(70);t.down()#2画目
    for i in range(20):
      t.forward(10);t.right(1)
  elif input == 'う'or input == 'ぅ':#うを描画
    t.up();t.goto(500,50);t.seth(30);t.down();t.forward(100)#1画目
    t.up();t.goto(420,236.25);t.seth(340);t.down()#2画目
    for i in range(18):
      t.forward(10);t.right(1)
    for i in range(18):
      t.right(5);t.forward(5)
    a = 0.1
    for i in range(10):
      t.forward(20);t.right(a);a = a*1.8
    for i in range(10):
      t.right(3);t.forward(16)
  elif input == 'え'or input == 'ぇ':#えを描画
    t.up();t.goto(500,50);t.seth(30);t.down();t.forward(100)#1画目
    t.up();t.goto(420,236.25);t.seth(345);t.down();t.forward(270);t.seth(130);t.forward(470);t.seth(310);t.forward(230)#2画目
    for i in range(10):
      t.right(13);t.forward(4)
    t.forward(150)
    for i in range(10):
      t.left(8);t.forward(4)
    t.forward(150)
  elif input == 'お'or input == 'ぉ':#おを描画
    t.up();t.goto(370,200);t.seth(350);t.down();t.forward(150)#1画目
    t.up();t.goto(435,100);t.seth(90);t.down();t.forward(335);t.seth(220);t.forward(90);t.seth(335);a=25;b=1#2画目
    for i in range(50):
      t.forward(a);t.right(b);a=a*0.9;b=b*1.01
    for i in range(36):
      t.right(5);t.forward(6)
    t.up();t.goto(580,150);t.seth(40);t.down();t.forward(100)#3画目
  elif input == 'か' or input == 'が':#かを描画
    t.up();t.goto(350,250);t.seth(350);t.down();t.forward(200)#1画目
    for i in range(15):
      t.right(5.5);t.forward(1)
    for i in range(100):
      t.forward(3);      t.right(0.5)
    t.seth(240);t.forward(70)
    t.up();t.goto(450,100);t.seth(105);t.down();t.forward(350)#2画目
    t.up();t.goto(640,200);t.seth(60);t.down();t.forward(150)#3画目
    if input == 'が':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'き'or input == 'ぎ':#きを描画
    t.up();t.goto(380,157.5);t.seth(355);t.down();t.forward(230)#1画目
    t.up();t.goto(365,250);t.seth(355);t.down();t.forward(250)#2画目
    t.up();t.goto(490,100);t.seth(80);t.down();t.forward(280);t.seth(190);t.forward(70)#3画目
    t.up();t.goto(360,390);t.seth(90);t.down()#4画目
    for i in range(12):
      t.forward(2);      t.left(4)
    for i in range(15):
      t.forward(10);      t.left(1)
    if input == 'ぎ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'く'or input == 'ぐ':#くを描画
    t.up();t.goto(600,50);t.seth(135);t.down();t.forward(340);t.seth(45);t.forward(350)#1画目
    if input == 'ぐ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'け'or input == 'げ':#けを描画
    t.up();t.goto(420,157.5);t.seth(90);t.down();t.forward(300);t.seth(285);t.forward(80)#1画目
    t.up();t.goto(510,200);t.seth(355);t.down();t.forward(150)#2画目
    t.up();t.goto(590,120);t.seth(90);t.down();t.forward(220)#3画目
    for i in range(15):
      t.right(2);      t.forward(10)
    if input == 'げ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'こ'or input == 'ご':#こを描画
    t.up();t.goto(420,157.5);t.seth(0);t.down()#1画目
    for i in range(10):
      t.forward(20);      t.right(2)
    t.seth(160);t.forward(50)
    t.up();t.goto(400,350);t.seth(80);t.down()#2画目
    for i in range(15):
      t.forward(7);      t.left(5)
    t.forward(150)
    if input == 'ご':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'さ'or input =='ざ':#さを描画
    t.up();t.goto(380,250);t.seth(355);t.down();t.forward(230)#1画目
    t.up();t.goto(490,150);t.seth(80);t.down();t.forward(200);t.seth(190);t.forward(70)#2画目
    t.up();t.goto(390,370);t.seth(90);t.down()#3画目
    for i in range(12):
      t.forward(2);      t.left(4)
    for i in range(14):
      t.forward(10);      t.left(1)
    if input == 'ざ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'し'or input == 'じ':#しを描画
    t.up();t.goto(420,157.5);t.seth(90);t.down();t.forward(200)#1画目
    for i in range(30):
      t.left(5);      t.forward(10)
  if input == 'じ':#濁点を描画
    t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'す'or input == 'ず':#すを描画
    t.up();t.goto(300,200);t.seth(358);t.down();t.forward(400)#1画目
    t.up();t.goto(550,100);t.seth(90);t.down();t.forward(210)#2画目
    for i in range(30):
      t.right(12);      t.forward(13)
    for i in range(10):
      t.right(5);      t.forward(25)
    if input == 'ず':#濁点を描画
       t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'せ'or input == 'ぜ':#せを描画
    t.up();t.goto(300,236.25);t.seth(358);t.down();t.forward(420)#1画目
    t.up();t.goto(600,127.5);t.seth(95);t.down();t.forward(200);t.seth(240);t.forward(40)#2画目
    t.up();t.goto(420,157.5);t.seth(90);t.down();t.forward(230);#3画目
    for i in range(14):
      t.left(6.5);      t.forward(5)
    t.forward(150)
    if input == 'ぜ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'そ'or input == 'ぞ':#そを描画
    t.up();t.goto(420,100);t.seth(353);t.down();t.forward(200);t.seth(150);t.forward(300);t.seth(355);t.forward(300);t.seth(170);a=2.5#1画目
    for i  in range(16):
      t.forward(20);     t.left(a);      a = a*1.15
    t.forward(100)
    if input == 'ぞ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'た'or input == 'だ':#たを描画
    t.up();t.goto(370,200);t.seth(356);t.down();t.forward(180)#1画目
    t.up();t.goto(480,100);t.seth(100);t.down();t.forward(350)#2画目
    t.up();t.goto(540,280);t.seth(356);t.down();t.forward(100)#3画目
    t.up();t.goto(540,350);t.seth(35);t.down()#4画目
    for i in range(10):
      t.forward(13);      t.left(2)
    if input == 'だ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'ち'or input == 'ぢ':#ちを描画
    t.up();t.goto(370,155);t.seth(358);t.down();t.forward(200)#1画目
    t.up();t.goto(470,100);t.seth(105);t.down();t.forward(200);t.seth(340)#2画目
    for i in range(11):
      t.forward(12);t.right(2)
    for i in range(17):
      t.forward(10);t.right(10)
    t.forward(120)
    if input == 'ぢ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'つ'or input =='づ'or input == 'っ':#つを描画
    t.up();t.goto(350,280);t.seth(345);t.down();t.forward(200)#1画目
    for i in range(35):
      t.right(5.5);t.forward(10)
    t.forward(120)
    if input == 'づ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'て'or input == 'で':#てを描画
    t.up();t.goto(300,180);t.seth(355);t.down();t.forward(350);t.seth(160);t.forward(125)#1画目
    for i in range(28):
      t.left(5);t.forward(18)
    if input == 'で':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'と'or input == 'ど':#とを描画
    t.up();t.goto(420,100);t.seth(80);t.down();t.forward(180)#1画目
    t.up();t.goto(600,225);t.seth(160);t.down();t.forward(150)#2画目
    for i in range(30):
      t.left(5.5);t.forward(10)
    t.forward(120)
    if input == 'ど':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
  elif input == 'な':#なを描画
    t.up();t.goto(340,157.5);t.seth(350);t.down();t.forward(150)#1画目
    t.up();t.goto(445,100);t.seth(120);t.down();t.forward(200)#2画目
    t.up();t.goto(540,150);t.seth(40);t.down();t.forward(100)#3画目
    t.up();t.goto(500,200);t.seth(90);t.down();t.forward(120)#4画目
    for i in range(20):
      t.forward(10);t.right(15)
    t.forward(100)
  elif input == 'に':#にを描画
    t.up();t.goto(420,157.5);t.seth(90);t.down();t.forward(300);t.seth(285);t.forward(80)#1画目
    t.up();t.goto(510,200);t.seth(355);t.down();t.forward(150)#2画目
    t.up();t.goto(510,380);t.seth(30);t.down()#3画目
    for i in range(10):
      t.left(2);t.forward(18)
  elif input == 'ぬ':#ぬを描画
    t.up();t.goto(420,157.5);t.seth(75);t.down()#1画目
    for i in range(10):
      t.forward(30);t.left(1)
    t.up();t.goto(570,135);t.seth(110);t.down()#2画目
    for i in range(10):
      t.forward(38);t.right(3)
    t.seth(250);t.forward(80);t.seth(310)
    for i in range(10):
      t.forward(32);t.right(4)
    for i in range(20):
      t.right(9);t.forward(19)
    for i in range(8):
      t.right(26);t.forward(13)
    for i in range(10):
      t.right(2);t.forward(15)
  elif input == 'ね':#ねを描画
    t.up();t.goto(420,120);t.seth(90);t.down();t.forward(400)#1画目
    t.up();t.goto(320,230);t.seth(350);t.down();t.forward(200);t.seth(130);t.forward(330);t.seth(315);t.forward(350)#2画目
    for i in range(10):
      t.right(12);t.forward(10)
    for i in range(10):
      t.right(3);t.forward(25)
    for i in range(20):
      t.forward(15);t.right(15)
    t.forward(100)
  elif input == 'の':#のを描画
    t.up();t.goto(560,157.5);t.seth(95);t.down()#1画目
    for i in range(10):
      t.forward(25);t.right(5)
    t.seth(225)
    for i in range(20):
      t.forward(10);t.right(5)
    for i in range(23):
      t.forward(10);t.right(2.5)
    for i in range(10):
      t.forward(5);t.right(7)
    a=2
    for i in range(4):
      t.forward(50);t.right(a);a=a**2.4
  elif input == 'は'or input == 'ば'or input =='ぱ':#はを描画
    t.up();t.goto(400,157.5);t.seth(90);t.down();t.forward(300);t.seth(285);t.forward(80)#1画目
    t.up();t.goto(510,200);t.seth(355);t.down();t.forward(150)#2画目
    t.up();t.goto(590,120);t.seth(90);t.down();t.forward(220)#3画目
    for i in range(15):
      t.right(2);t.forward(7)
    for i in range(25):
      t.right(11);t.forward(7)
    t.forward(100)
    if input == 'ば':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
    if input == 'ぱ':#半濁点を描画
      t.up();t.goto(800,120);t.down()
      for i in range(10):
        t.right(36);t.forward(10)
  elif input == 'ひ'or input == 'び'or input == 'ぴ':#ひを描画
    t.up();t.goto(300,157.5);t.seth(355);t.down();t.forward(150);t.seth(160)#1画目
    for i in range(35):
      t.forward(10);t.left(3)
    for i in range(10):
      t.forward(3);t.left(8)
    for i in range(30):
      t.forward(10);t.left(2)
    t.seth(80)
    for i in range(15):
      t.forward(10);t.left(2)
    if input == 'び':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
    if input == 'ぴ':#半濁点を描画
      t.up();t.goto(800,120);t.down()
      for i in range(10):
        t.right(36);t.forward(10)
  elif input == 'ふ'or input == 'ぶ'or input == 'ぷ':#ふを描画
    t.up();t.goto(550,120);t.seth(50);t.down();t.forward(150);t.seth(170);t.forward(70)#1画目
    t.up();t.goto(530,290);t.seth(50);t.down();t.forward(150)#2画目
    for i in range(10):
      t.right(14);t.forward(10)
    t.forward(80)
    t.up();t.goto(380,380);t.seth(50);t.down();t.forward(100);t.seth(300);t.forward(70)#3画目
    t.up();t.goto(700,350);t.seth(50);t.down();t.forward(100)#4画目
    if input == 'ぶ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
    if input == 'ぷ':#半濁点を描画
      t.up();t.goto(800,120);t.down()
      for i in range(10):
        t.right(36);t.forward(10)
  elif input == 'へ'or input == 'べ'or input == 'ぺ':#へを描画
    t.up();t.goto(325,380);t.seth(320);t.down();t.forward(200);t.seth(40);t.forward(300)#1画目
    if input == 'べ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
    if input == 'ぺ':#半濁点を描画
      t.up();t.goto(800,120);t.down()
      for i in range(10):
        t.right(36);t.forward(10)
  elif input == 'ほ'or input == 'ぼ'or input == 'ぽ':#ほを描画
    t.up();t.goto(400,157.5);t.seth(90);t.down();t.forward(300);t.seth(285);t.forward(80)#1画目
    t.up();t.goto(510,160);t.seth(355);t.down();t.forward(150)#2画目
    t.up();t.goto(510,240);t.seth(355);t.down();t.forward(150)#3画目
    t.up();t.goto(590,160);t.seth(90);t.down();t.forward(170)#4画目
    for i in range(15):
      t.right(2);t.forward(7)
    for i in range(25):
      t.right(11);t.forward(7)
    t.forward(100)
    if input == 'ぼ':#濁点を描画
      t.up();t.goto(800,120);t.seth(45);t.down();t.forward(100);t.up();t.goto(850,70);t.seth(45);t.down();t.forward(100)
    if input == 'ぽ':#半濁点を描画
      t.up();t.goto(800,120);t.down()
      for i in range(10):
        t.right(36);t.forward(10)
  elif input == 'ま':#まを描画
    t.up();t.goto(495,200);t.seth(355);t.down();t.forward(150)#1画目
    t.up();t.goto(495,280);t.seth(355);t.down();t.forward(150)#2画目
    t.up();t.goto(560,160);t.seth(90);t.down();t.forward(170)#3画目
    for i in range(15):
      t.right(2);t.forward(7)
    for i in range(25):
      t.right(11);t.forward(7)
    t.forward(100)
  elif input == 'み':#みを描画
    t.up();t.goto(450,120);t.seth(350);t.down();t.forward(150);t.seth(120);t.forward(300)#1画目
    for i in range(13):
      t.right(18);  t.forward(12)
    for i in range(10):
      t.forward(30);t.right(3.5)
    t.up();t.goto(670,290);t.seth(110);t.down()#2画目
    for i in range(10):
      t.forward(15);t.right(2)
  elif input == 'む':#むを描画
    t.up();t.goto(320,170);t.seth(355);t.down();t.forward(200)#1画目
    t.up();t.goto(420,100);t.seth(90);t.down();t.forward(280)#2画目
    for i in range(20):
      t.forward(15);t.right(18)
    t.forward(50)
    for i in range(10):
      t.left(9);t.forward(2)
    t.forward(150)
    for i in range(10):
      t.left(8.5);t.forward(3)
    t.forward(100)
    t.up();t.goto(600,157.5);t.seth(50);t.down();t.forward(100)
  elif input == 'め':#めを描画
    t.up();t.goto(420,157.5);t.seth(75);t.down()#1画目
    for i in range(10):
      t.forward(30);t.left(1)
    t.up();t.goto(570,135);t.seth(110);t.down()#2画目
    for i in range(10):
      t.forward(38);t.right(3)
    t.seth(250);t.forward(80);t.seth(310)
    for i in range(10):
      t.forward(32);t.right(4)
    for i in range(20):
      t.right(9);t.forward(19)
  elif input == 'も':#もを描画
    t.up();t.goto(420,200);t.seth(5);t.down();t.forward(140)#1画目
    t.up();t.goto(420,280);t.seth(5);t.down();t.forward(140)#2画目
    t.up();t.goto(495,160);t.seth(100);t.down();t.forward(190)#3画目
    for i in range(35):
      t.left(6);t.forward(8)
    t.forward(50)
  elif input == 'や'or input == 'ゃ':#やを描画
    t.up();t.goto(300,315);t.seth(340);t.down();t.forward(200)#1画目
    for i in range(29):
      t.forward(5);t.right(7)
    t.forward(100)
    t.up();t.goto(380,180);t.seth(40);t.down();t.forward(100);t.seth(200);t.forward(75);#2画目
    t.up();t.goto(340,190);t.seth(70);t.down();t.forward(300)#3画目
  elif input == 'ゆ'or input == 'ゅ':#ゆを描画
    t.up();t.goto(400,157.5);t.seth(80);t.down();t.forward(200);t.seth(270);t.forward(75);a=7;b=8#1画目
    for i in range(13):
      t.right(a);t.forward(b);a=a*0.99;b=b*1.1
    for i in range(18):
      t.right(8.5);t.forward(11)
    t.forward(70)
    for i in range(10):
      t.right(10);t.forward(4)
    t.up();t.goto(560,100);t.seth(90);t.down();t.forward(200)#2画目
    for i in range(15):
      t.right(2);t.forward(10)
  elif input == 'よ'or input == 'ょ':#よを描画
    t.up();t.goto(560,250);t.seth(355);t.down();t.forward(100)#1画目
    t.up();t.goto(560,120);t.seth(90);t.down();t.forward(300)#2画目
    for i in range(10):
      t.right(10);t.forward(10)
    t.forward(20)
    for i in range(10):
      t.right(20);t.forward(10)
    for i in range(9):
      t.right(0.1);t.forward(17)
  elif input == 'ら':#らを描画
    t.up();t.goto(500,157.5);t.seth(25);t.down();t.forward(150);t.seth(170);t.forward(80)#1画目
    t.up();t.goto(490,240);t.seth(100);t.down();t.forward(150);t.seth(350);t.forward(100)#2画目
    for i in range(18):
      t.right(10);t.forward(10)
    t.forward(80)
  elif input == 'り':#りを描画
    t.up();t.goto(480,157.5);t.seth(90);t.down();t.forward(180);t.seth(290);t.forward(50)#1画目
    t.up();t.goto(640,157.5);t.seth(90);t.down();t.forward(200)#2画目
    for i in range(15):
      t.right(2);t.forward(10)
  elif input == 'る':#るを描画
    t.up();t.goto(420,100);t.seth(353);t.down();t.forward(200);t.seth(140);t.forward(330);t.seth(330)#1画目
    for i in range(6):
      t.forward(50);t.right(10)
    a=5;b=7
    for i in range(10):
      t.forward(a);t.right(b);a=a*0.99;b=b*1.05
    t.seth(120);t.forward(50)
    for i in range(25):
      t.right(2);t.forward(10)
    for i in range(11):
      t.right(20);t.forward(10)
    t.forward(55)
  elif input == 'れ':#れを描画
    t.up();t.goto(420,120);t.seth(90);t.down();t.forward(400)#1画目
    t.up();t.goto(320,230);t.seth(350);t.down();t.forward(200);t.seth(130);t.forward(330);t.seth(315);t.forward(350)#2画目
    for i in range(10):
      t.right(12);t.forward(10)
    t.seth(95);t.forward(250)
    for i in range(10):
      t.left(12);t.forward(2)
    t.forward(100)
  elif input =='ろ':#ろを描画
    t.up();t.goto(420,100);t.seth(353);t.down();t.forward(200);t.seth(140);t.forward(330);t.seth(330)#1画目
    for i in range(6):
      t.forward(50);t.right(10)
    a=5;b=7
    for i in range(10):
      t.forward(a);t.right(b);a=a*0.99;b=b*1.05
    t.seth(120);t.forward(50)
    for i in range(25):
      t.right(2);t.forward(10)
  elif input =='わ':#わを描画
    t.up();t.goto(420,120);t.seth(90);t.down();t.forward(400)#1画目
    t.up();t.goto(320,230);t.seth(350);t.down();t.forward(200);t.seth(130);t.forward(330);t.seth(315);t.forward(300)#2画目
    for i in range(10):
      t.right(9);t.forward(9)
    for i in range(10):
      t.right(10);t.forward(25)
    t.forward(100)
  elif input == 'を':#をを描画
    t.up();t.goto(370,155);t.seth(358);t.down();t.forward(200)#1画目
    t.up();t.goto(470,100);t.seth(115);t.down();t.forward(200);t.seth(300)#2画目
    for i in range(11):
      t.forward(13);t.right(14)
    t.forward(50)
    t.up();t.goto(650,220);t.seth(150);t.down();t.forward(200)#3画目
    for i in range(10):
      t.forward(20);t.left(15)
    t.forward(120)
  elif input == 'ん':#んを描画
    t.up();t.goto(550,130);t.seth(110);t.down();t.forward(350);t.seth(310);t.forward(200);t.seth(90)#1画目
    for i in range(15):
      t.left(5);t.forward(15)
    for i in range(10):
      t.left(8);t.forward(10)
    t.forward(90)

# %%
#@title メイン処理
t.initializeTurtle(initial_speed=5,initial_window_size=(1120,630))
t.hideturtle()
t.speed(13)
for i in title:#for文で入力されたひらがなの文字列を定義関数drawに入れて回す
  draw(i)
  time.sleep(1.5)
  t.clear()
# Out:
#       <svg width="1120" height="630">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=hidden transform="rotate(150,715.0,329.904) translate(697.0, 311.904)">
# ...
